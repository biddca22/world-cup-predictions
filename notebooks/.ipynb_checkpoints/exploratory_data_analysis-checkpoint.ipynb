# %%
# ------------------------------------------------------
# 1. Load data
# ------------------------------------------------------
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)


tournament_palette = sns.color_palette("viridis", n_colors=6)

squads = pd.read_csv('../data-processed/squads_clean.csv')
substitutions = pd.read_csv('../data-processed/substitutions_clean.csv')
bookings = pd.read_csv('../data-processed/bookings_clean.csv')
goals = pd.read_csv('../data-processed/goals_clean.csv')
matches_weather = pd.read_csv('../data-processed/matches_clean_weather.csv')
matchbox = pd.read_csv('../data-processed/MatchBoxData_clean.csv')

print("All files loaded successfully!")

# Dictionary to store and display column names for each df
datasets = {
    "Squads": squads,
    "Substitutions": substitutions,
    "Bookings": bookings,
    "Goals": goals,
    "Matches Weather": matches_weather,
    "MatchBox Data": matchbox
}

for name, df in datasets.items():
    print(f"--- {name} Overview ---")
    df.info()
    print("\n" + "="*50 + "\n")
# Out:
# All files loaded successfully!
# --- Squads Overview ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          192 non-null    int64
#  1   country_full  192 non-null    object
#  2   country_abrv  192 non-null    object
#  3   rank_date     192 non-null    object
#  4   median_age    192 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 7.6+ KB
#
# ==================================================
#
# --- Substitutions Overview ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2411 entries, 0 to 2410
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tournament_id      2411 non-null   object
#  1   match_id           2411 non-null   object
#  2   match_date         2411 non-null   object
#  3   stage_name         2411 non-null   object
#  4   team_id            2411 non-null   object
#  5   team_name          2411 non-null   object
#  6   team_code          2411 non-null   object
#  7   home_team          2411 non-null   int64
#  8   away_team          2411 non-null   int64
#  9   minute_label       2411 non-null   object
#  10  minute_regulation  2411 non-null   int64
#  11  minute_stoppage    2411 non-null   int64
#  12  minute_total       2411 non-null   int64
#  13  match_period       2411 non-null   object
#  14  player_id_in       2411 non-null   object
#  15  family_name_in     2411 non-null   object
#  16  given_name_in      2411 non-null   object
#  17  shirt_number_in    2411 non-null   int64
#  18  player_id_out      2411 non-null   object
#  19  family_name_out    2411 non-null   object
#  20  given_name_out     2411 non-null   object
#  21  shirt_number_out   2411 non-null   int64
# dtypes: int64(7), object(15)
# memory usage: 414.5+ KB
#
# ==================================================
#
# --- Bookings Overview ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511 entries, 0 to 1510
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tournament_id  1511 non-null   object
#  1   match_id       1511 non-null   object
#  2   match_date     1511 non-null   object
#  3   stage_name     1511 non-null   object
#  4   match_period   1511 non-null   object
#  5   team_id        1511 non-null   object
#  6   team_name      1511 non-null   object
#  7   home_team      1511 non-null   int64
#  8   away_team      1511 non-null   int64
#  9   card_minute    1511 non-null   int64
#  10  is_yellow      1511 non-null   bool
#  11  is_red         1511 non-null   bool
# dtypes: bool(2), int64(3), object(7)
# memory usage: 121.1+ KB
#
# ==================================================
#
# --- Goals Overview ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key_id             965 non-null    int64
#  1   goal_id            965 non-null    object
#  2   tournament_id      965 non-null    object
#  3   match_id           965 non-null    object
#  4   match_name         965 non-null    object
#  5   match_date         965 non-null    object
#  6   stage_name         965 non-null    object
#  7   team_id            965 non-null    object
#  8   team_name          965 non-null    object
#  9   team_code          965 non-null    object
#  10  home_team          965 non-null    int64
#  11  away_team          965 non-null    int64
#  12  player_id          965 non-null    object
#  13  family_name        965 non-null    object
#  14  given_name         965 non-null    object
#  15  shirt_number       965 non-null    int64
#  16  player_team_id     965 non-null    object
#  17  player_team_name   965 non-null    object
#  18  player_team_code   965 non-null    object
#  19  minute_label       965 non-null    object
#  20  minute_regulation  965 non-null    int64
#  21  minute_stoppage    965 non-null    int64
#  22  match_period       965 non-null    object
#  23  own_goal           965 non-null    bool
#  24  penalty            965 non-null    bool
#  25  minute_total       965 non-null    int64
# dtypes: bool(2), int64(7), object(17)
# memory usage: 183.0+ KB
#
# ==================================================
#
# --- Matches Weather Overview ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tournament_id           384 non-null    object
#  1   match_id                384 non-null    object
#  2   stage_name              384 non-null    object
#  3   group_stage             384 non-null    int64
#  4   knockout_stage          384 non-null    int64
#  5   match_date              384 non-null    object
#  6   match_time              384 non-null    object
#  7   match_datetime          384 non-null    object
#  8   city_name               384 non-null    object
#  9   country_name            384 non-null    object
#  10  home_team_id            384 non-null    object
#  11  home_team_name          384 non-null    object
#  12  home_team_code          384 non-null    object
#  13  away_team_id            384 non-null    object
#  14  away_team_name          384 non-null    object
#  15  away_team_code          384 non-null    object
#  16  home_team_score         384 non-null    int64
#  17  away_team_score         384 non-null    int64
#  18  home_team_score_margin  384 non-null    int64
#  19  away_team_score_margin  384 non-null    int64
#  20  extra_time              384 non-null    int64
#  21  penalty_shootout        384 non-null    int64
#  22  temp0                   384 non-null    float64
#  23  temp1                   384 non-null    float64
#  24  temp2                   384 non-null    float64
#  25  atemp0                  384 non-null    float64
#  26  atemp1                  384 non-null    float64
#  27  atemp2                  384 non-null    float64
#  28  humid0                  384 non-null    float64
#  29  humid1                  384 non-null    float64
#  30  humid2                  384 non-null    float64
#  31  wind0                   384 non-null    float64
#  32  wind1                   384 non-null    float64
#  33  wind2                   384 non-null    float64
# dtypes: float64(12), int64(8), object(14)
# memory usage: 102.1+ KB
#
# ==================================================
#
# --- MatchBox Data Overview ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hname           384 non-null    object
#  1   aname           384 non-null    object
#  2   hPossession     384 non-null    int64
#  3   aPossession     384 non-null    int64
#  4   hshotsOnTarget  384 non-null    int64
#  5   ashotsOnTarget  384 non-null    int64
#  6   hshots          384 non-null    int64
#  7   ashots          384 non-null    int64
#  8   hyellowCards    384 non-null    int64
#  9   ayellowCards    384 non-null    int64
#  10  hredCards       384 non-null    int64
#  11  aredCards       384 non-null    int64
#  12  hfouls          384 non-null    int64
#  13  afouls          384 non-null    int64
#  14  tournament_id   384 non-null    object
# dtypes: int64(12), object(3)
# memory usage: 45.1+ KB
#
# ==================================================

# %%
# ------------------------------------------------------
# 2. Feature engineering
# ------------------------------------------------------
# 1. Avg weather variables per match
# Mean of the 3 hourly readings (start, +1hr, +2hr)
matches_weather['avg_temp'] = matches_weather[['temp0', 'temp1', 'temp2']].mean(axis=1)
matches_weather['avg_humid'] = matches_weather[['humid0', 'humid1', 'humid2']].mean(axis=1)
matches_weather['avg_wind'] = matches_weather[['wind0', 'wind1', 'wind2']].mean(axis=1)

# 2. Total goals per match
# Group by match_id to count how many goals happened in each game
goals_per_match = goals.groupby('match_id').size().reset_index(name='total_goals')

# 3. Merge total goals into main match df
# Use left merge to keep all matches, filling 0 for 0-0 draws if any are missing from goals df
matches_full = pd.merge(matches_weather, goals_per_match, on='match_id', how='left')
matches_full['total_goals'] = matches_full['total_goals'].fillna(0)

# 4. Extract year from tournament ID for cleaner sorting
print("Data preprocessing complete.")
matches_full.head(3)
# Out:
# Data preprocessing complete.
#   tournament_id   match_id   stage_name  group_stage  knockout_stage  \
# 0       WC-2002  M-2002-01  group stage            1               0
# 1       WC-2002  M-2002-02  group stage            1               0
# 2       WC-2002  M-2002-03  group stage            1               0
#
#    match_date match_time       match_datetime city_name country_name  ...  \
# 0  2002-05-31      20:30  2002-05-31 20:30:00     Seoul  South Korea  ...
# 1  2002-06-01      15:30  2002-06-01 15:30:00   Niigata        Japan  ...
# 2  2002-06-01      18:00  2002-06-01 18:00:00     Ulsan  South Korea  ...
#
#      humid0     humid1    humid2      wind0     wind1     wind2   avg_temp  \
# 0  90.94624  93.252205  93.53798  10.483357  9.693296  9.422101  17.364000
# 1  65.32017  66.560630  69.92575   6.915374  6.638072  7.100310  22.646000
# 2  76.21286  80.208720  84.48504  10.137692  9.366919  4.452954  21.379499
#
#    avg_humid  avg_wind  total_goals
# 0  92.578808  9.866251          1.0
# 1  67.268850  6.884585          2.0
# 2  80.302207  7.985855          3.0
#
# [3 rows x 38 columns]

# %%
# ------------------------------------------------------
# 3. Univariate analysis - Goal distribution
# ------------------------------------------------------
# Histogram of goals per match
plt.figure(figsize=(10, 6))
sns.countplot(
    data=matches_full, 
    x='total_goals', 
    hue='total_goals',     
    palette='Blues_d', 
    legend=False           
)

plt.title('Distribution of Goals per Match (All Tournaments)', fontsize=16)
plt.xlabel('Number of Goals', fontsize=12)
plt.ylabel('Count of Matches', fontsize=12)

# Calculate mean goals
mean_goals = matches_full['total_goals'].mean()
plt.axvline(mean_goals, color='red', linestyle='--', label=f'Mean Goals: {mean_goals:.2f}')
plt.legend()
plt.show()

print(f"Skewness of goals: {matches_full['total_goals'].skew()}")
# Out:
# Skewness of goals: 0.7812915560886982

# %%
# Right-skewed distribution (skewness ~0.78) with an average of 2.51 goals 
# per match, most games feature 2-3 goals while high-scoring matches are 
# rare outliers. It resembles a Poisson distribution.

# %%
# ------------------------------------------------------
# 3. Bivariate analysis - Goals vs. Tournament
# ------------------------------------------------------
plt.figure(figsize=(12, 6))
# Boxplot to see the spread (median, quartiles) per tournament
sns.boxplot(data=matches_full, x='tournament_id', hue='tournament_id', y='total_goals', palette="Set2", legend=False)

plt.title('Goals per Match Distribution by Tournament', fontsize=16)
plt.xlabel('Tournament', fontsize=12)
plt.ylabel('Goals Scored', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Goals seems largely consistent across the tournaments, notable exception would
# be 2014, with higher median of 3, and greater variability

# %%
# To do: timing of goals and subs; temperature distribution; distribution of 
# squad median ages; compare red cards in group stage vs knockout matches, etc.

# %%
# Also: “15-minute interval win probability” model using only:
# 1.	current score
# 2.	shots difference up to minute t
# 3.	shots on target difference up to minute t
# 4.	possession up to minute t
# 5.	cards/fouls up to minute t
# 6.	time remaining
# 7.	pre-match ranking difference

# Create dataset: for each match, for 6 15-minute chunks, compute
# ⦁	current goal difference
# ⦁	cumulative shots difference so far
# ⦁	cumulative shots on target difference
# ⦁	cumulative yellow/red cards
# ⦁	time remaining (90 - minute)
# ⦁	pre-match ranking difference
# 384 matches * 6 rows each = 2,304 rows

# Train a classifier (random forest, gradient boosting)
# Feed the model the state of the match at minute t
# Model tries to output P(home team wins | current match state at minute t)

# Generate a probability curve
# Timeline from minute 1 to 90
